# %%
from annotated_data import annotated_data
from annotated_data_corrected import annotated_data_corrected

# %%
correct = 0
for i in range(len(annotated_data)):
    line_is_correct = True
    for j in range(len(annotated_data[i][1])):
        print(annotated_data[i][1][j], annotated_data_corrected[i][1][j])
        if annotated_data[i][1][j] != annotated_data_corrected[i][1][j]:
            line_is_correct = False
    if line_is_correct:
        correct += 1
    

print("found {} correct out of {}".format(correct, len(annotated_data)))
print("for a total correct score of {}".format(correct/(len(annotated_data))))
# Out:
# 12 12
#
# egg whites  egg whites
# 12 12
#
# egg yolks  egg yolks
# 1/2 3/2
# cup cup
# sugar  sugar
# 3/4 3/4
# cup cup
# rye whiskey  rye whiskey
# 12 12
#
# egg whites  egg whites
# 3/4 3/4
# cup cup
# brandy  brandy
# 1/2 1/2
# cup cup
# rum  rum
# 2 2
# cup cup
# heavy cream  heavy cream
# 0 0
#
# ground nutmeg  ground nutmeg
# 18 18
#
# fresh chestnuts  fresh chestnuts
# 1/2 5/2
# pound pound
# stew meat  veal stew meat
# 4 4
# tablespoon tablespoon
# olive oil  olive oil
# 1/2 3/2
# cup cup
# onion  onion
# 1/2 3/2
# tablespoon tablespoon
#  garlic
# 1 1
#
# bay leaf  bay leaf
# 1/2 5/2
# cup cup
# salt chicken broth  canned low-salt chicken broth
# 3/4 3/4
# cup cup
# dry white wine  dry white wine
# 6 6
#
# medium carrots  medium carrots
# 3 3
# tablespoon tablespoon
# fresh sage  fresh sage
# 2 2
# tablespoon tablespoon
# unsalted butter  unsalted butter
# 1/4 5
#  slices
# slices thick brioche Pepperidge Farm crusts  brioche
# 3 3
#
# large eggs  extra-large eggs
# 2 2
#
# large egg yolks  extra-large egg yolks
# 1/4 1/4
# cup cup
# brown sugar  brown sugar
# 1/2 3/2
# cup cup
# heavy cream  heavy cream
# 1/4 5/4
# cup cup
# whole milk  whole milk
# 1 1
# teaspoon teaspoon
# pure vanilla extract  vanilla extract
# 1/2 1/2
# teaspoon teaspoon
# ground cinnamon  ground cinnamon
# 1/4 1/4
# teaspoon teaspoon
# nutmeg  nutmeg
# 1/4 1/4
# teaspoon teaspoon
#
# 3/4 3/4
# cup cup
# bittersweet chocolate  bittersweet chocolate
# 1 1
# tablespoon tablespoon
# granulated sugar top  granulated sugar
# 3 3/4
# cup pound
# Stilton  Stilton
# 6 6
# ounce ounce
# cream cheese  cream cheese
# 3 3
# tablespoon tablespoon
# green peppercorns  green peppercorns
# 1/4 1/4
# cup cup
# dry Sherry  medium-dry Sherry
# 1/2 1/2
# ounce cups
# whole almonds  whole almonds
# 1 1
# cup cup
# sugar  sugar
# 1/4 1/4
# teaspoon teaspoon
# ground cinnamon  ground cinnamon
# 1/8 1/8
# teaspoon teaspoon
#
# 1 1
#
# large egg  large egg
# 2 2
#
#  large egg white
# 1/4 1/4
# teaspoon teaspoon
# almond extract  almond extract
# 3/4 3/4
# cup cup
# bittersweet semisweet chocolate  bittersweet or semisweet chocolate
# 2 2
# tablespoon tablespoon
# butter  butter
# 2 2
# tablespoon tablespoon
# flour  flour
# 1/4 5/4
# cup cup
# milk  milk
# 0 0
#
#
# 0 0
#
# ground pepper  ground pepper
# 1/2 1/2
# teaspoon teaspoon
# fresh lemon  fresh lemon zest
# 1/2 3/2
# tablespoon tablespoon
#  lemon juice
# 1/3 1/3
# cup cup
# virgin olive oil  extra-virgin olive oil
# 1/4 1/4
# oz cup
# Kalamata olives  pitted Kalamata olives
# 6 3
# tablespoon tablespoon
# fresh oregano  fresh oregano
# 3 1
#
# whole Spanish mackerel  whole Spanish mackerel or bluefish
# 2 2
# tablespoon tablespoon
# vegetable oil  vegetable oil
# 6 6
#
# lemon slices  lemon slices
# 0 0
#
# Special equipment 22-inch grill kitchen string  Special equipment 22-inch grill kitchen string
# 2 2
# clove clove
#  garlic
# 2 2
# teaspoon teaspoon
# peeled fresh ginger   fresh ginger
# 1 1
# tablespoon tablespoon
# vegetable oil  vegetable oil
# 1 1
# teaspoon teaspoon
# mustard seeds  mustard seeds
# 6 3/4
# oz cup
# dried apricots  dried apricots
# 1/2 1/3
# oz cup
# dried currants  dried currants
# 3/4 3/4
# cup cup
#
# 1/3 1/3
# cup cup
# wine vinegar  red-wine vinegar
# 1/4 1/4
# cup cup
# sugar  sugar
# 3/4 3/4
# teaspoon teaspoon
#
# 1/4 2
# tablespoon tablespoon
# stick butter  butter
# 1/4 1/4
# cup cup
# olive oil  olive oil
# 2 2
# clove clove
#  garlic
# 4 4
# cube slice
# French bread slices  French bread
# 1 1
#
# recipe pate chou  recipe pate chou
# 1 1
# cup cup
# pastry cream  pastry cream
# 1/2 1/2
# cup cup
# heavy cream  heavy cream
# 1 1
#
# recipe chocolate sauce  recipe chocolate sauce
# 0 0
#
# Assorted candy decorations Red Hots  Assorted candy decorations
# 70 70
#
# Special equipment Large pastry bag cloth leaves  Special equipment Large pastry bag cloth leaves
# 1/2 5/2
# cup cup
# purpose flour  purpose flour
# 1/4 1/4
# cup cup
# cocoa powder  unsweetened cocoa powder
# 1/2 1/2
# teaspoon teaspoon
# baking powder  baking powder
# 1/2 1/2
# teaspoon teaspoon
#
# 1/4 1/4
# teaspoon teaspoon
# baking soda  baking soda
# 1/2 1/2
# teaspoon teaspoon
# ground cinnamon optional  ground cinnamon
# 3 3
# ounce ounce
# bittersweet chocolate  bittersweet chocolate
# 2 1
# cup cup
# sticks butter room temperature  butter room
# 1/3 4/3
# cup cup
# sugar  sugar
# 1 1
#
# large egg  large egg
# 1/2 1/2
# teaspoon teaspoon
# vanilla extract  vanilla extract
# 0 0
#
# Sprinkles  Sprinkles
# 0 0
#
# Royal Icing  Royal Icing
# 2 2
# tablespoon tablespoon
# coffee  coffee
# 1 1
# ounce ounce
# semisweet chocolate  semisweet chocolate
# 1/4 1/4
# teaspoon teaspoon
# vanilla  vanilla
# 1/8 1/8
# teaspoon teaspoon
# cornstarch  cornstarch
# 0 0
#
# Pinch cinnamon  cinnamon
# 1 1
# cup cup
#  all purpose flour
# 1/2 1/2
# teaspoon teaspoon
# ground cinnamon  ground cinnamon
# 1/2 1/2
# teaspoon teaspoon
# baking soda  baking soda
# 1/4 1/4
# teaspoon teaspoon
#
# found 60 correct out of 100
# for a total correct score of 0.6
